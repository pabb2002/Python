# %% [markdown]
# # Importing Libraries and Reading Dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Originaldf=pd.read_csv('owid-energy-data.csv')

# %%
Originaldf.head()
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_consumption  \
# ...

# %%
df=Originaldf.dropna()
df
# Out:
#       iso_code        country  year  coal_prod_change_pct  \
# 838        ARG      Argentina  2011                38.462
# 839        ARG      Argentina  2012                 5.556
# 840        ARG      Argentina  2013               -12.632
# 841        ARG      Argentina  2014               -31.325
# 842        ARG      Argentina  2015               -40.351
# ...        ...            ...   ...                   ...
# 16175      USA  United States  2014                 1.422
# 16176      USA  United States  2015               -11.533
# 16177      USA  United States  2016               -18.271
# 16178      USA  United States  2017                 6.534
# 16179      USA  United States  2018                -1.676
#
#        coal_prod_change_twh  gas_prod_change_pct  gas_prod_change_twh  \
# 838                   0.164               -3.280              -12.792
# 839                   0.033               -2.722              -10.266
# ...

# %% [markdown]
# # United States Data Over Time

# %%
US=df[df['country']=='United States']

# %%
plt.figure()
plot=sns.lineplot(x='year',y='solar_energy_per_capita',data=US)
plot.set_xlabel('Year')
plot.set_ylabel('Solar Energy Per Capita')
plot.set_title('US Solar Energy Over Time')
plt.xlim(2000,2018)
plt.show()

# %%
plt.figure()
plot=sns.lineplot(x='year',y='wind_energy_per_capita',data=US)
plot.set_xlabel('Year')
plot.set_ylabel('Wind Energy Per Capita')
plot.set_title('US Wind Energy Over Time')
plt.xlim(2000,2018)
plt.show()

# %%
plt.figure(figsize=(10,6))

column=['year','solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']
USEnergyData=US[column].set_index('year')

plot=sns.lineplot(data=USEnergyData)
plot.set_xlabel('Year')
plot.set_title('US Energy Metrics Over Time')
plt.xlim(2000,2018)
plt.show()

# %% [markdown]
# # Spain Data Over Time

# %%
df['country'].unique()
# Out:
# array(['Argentina', 'Brazil', 'Canada', 'France', 'Germany', 'Mexico',
#        'Spain', 'United Kingdom', 'United States'], dtype=object)

# %%
Spain=df[df['country']=='Spain']

# %%
plt.figure(figsize=(10,6))

column=['year','solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']
SpainEnergyData=Spain[column].set_index('year')

plot=sns.lineplot(data=SpainEnergyData)
plot.set_xlabel('Year')
plot.set_title('Spain Energy Metrics Over Time')
plt.xlim(2001,2016)
plt.show()

# %% [markdown]
# # India Data Over Time

# %%
India=Originaldf[Originaldf['country']=='India'].set_index('year')

# %%
India.tail()
# Out:
#      iso_code country  coal_prod_change_pct  coal_prod_change_twh  \
# year
# 2017      IND   India                 0.846                27.922
# 2018      IND   India                 6.775               225.592
# 2019      IND   India                -1.584               -56.333
# 2020      IND   India                 0.685                23.954
# 2021      IND   India                   NaN                   NaN
#
#       gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# year
# 2017                4.180               11.110                0.534
# 2018               -0.724               -2.004               -2.201
# 2019               -2.135               -5.869               -4.881
# 2020              -11.691              -31.454               -6.565
# 2021                  NaN                  NaN                  NaN
#
#       oil_prod_change_twh  energy_cons_change_pct  energy_cons_change_twh  \
# year
# ...

# %%
column=['solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']

IndiaEnergyData=India.loc[2000:2020][column]

# %%
plt.figure(figsize=(10,6))

plot=sns.lineplot(data=IndiaEnergyData)

plot.set_xlabel('Year')
plot.set_title('India Energy Metrics Over Time')
plt.xticks(np.arange(2000,2021))
plt.show()

# %% [markdown]
# # World Data Over Time

# %%
world=Originaldf[Originaldf['country']=='World'].set_index('year').loc[2000:2020]

plt.figure(figsize=(15,10))

column=['solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']
WorldEnergyData=world[column]
plot=sns.lineplot(data=WorldEnergyData)
plot.set_xlabel('Year')
plot.set_title('World Energy Metrics Over Time')
plt.xticks(np.arange(2000,2021))
plt.show()

# %% [markdown]
# # Solar Energy Data For Each Country in 2019 and 2020

# %%
'''
CountriesArray=Originaldf['country'].unique()
multiIndex=pd.MultiIndex.from_tuples([tuple(np.arange(1900,2021)),tuple(CountriesArray)])
multiIndex
column=['solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']

pd.DataFrame(data=Originaldf,columns=column,index=multiIndex)
'''
# Out:
# "\nCountriesArray=Originaldf['country'].unique()\nmultiIndex=pd.MultiIndex.from_tuples([tuple(np.arange(1900,2021)),tuple(CountriesArray)])\nmultiIndex\ncolumn=['solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']\n\npd.DataFrame(data=Originaldf,columns=column,index=multiIndex)\n"

# %%
sortedData=Originaldf.set_index(['year']).sort_index()
sortedData
# Out:
#       iso_code         country  coal_prod_change_pct  coal_prod_change_twh  \
# year
# 1900       AFG     Afghanistan                   NaN                   NaN
# 1900       MYS        Malaysia                   NaN                   NaN
# 1900       GBR  United Kingdom                   NaN                   NaN
# 1900       NaN  Czechoslovakia                   NaN                   NaN
# 1900       IRQ            Iraq                   NaN                   NaN
# ...        ...             ...                   ...                   ...
# 2021       NLD     Netherlands                   NaN                   NaN
# 2021       MLT           Malta                   NaN                   NaN
# 2021  OWID_WRL           World                   NaN                   NaN
# 2021       USA   United States                   NaN                   NaN
# 2021       TJK      Tajikistan                   NaN                   NaN
#
# ...

# %%
column=['country','solar_consumption','solar_elec_per_capita','solar_energy_per_capita','wind_consumption','wind_elec_per_capita','wind_energy_per_capita']

sortedDataPastDecade=sortedData[column].loc[2010:2020].reset_index()
sortedDataPastDecade
# Out:
#       year       country  solar_consumption  solar_elec_per_capita  \
# 0     2010   North Korea                NaN                  0.000
# 1     2010       Belgium              1.460                 51.194
# 2     2010    Mozambique                NaN                  0.000
# 3     2010        Cyprus              0.018                  8.988
# 4     2010  Asia Pacific             17.566                    NaN
# ...    ...           ...                ...                    ...
# 2565  2020        Jordan                NaN                215.620
# 2566  2020  Asia Pacific           1160.283                    NaN
# 2567  2020         Japan            204.580                621.776
# 2568  2020         Tonga                NaN                  0.000
# 2569  2020       Georgia                NaN                  0.000
#
#       solar_energy_per_capita  wind_consumption  wind_elec_per_capita  \
# 0                         NaN               NaN                 0.000
# ...

# %%
plt.figure(figsize=(100,50))

solarEnergy19=sortedDataPastDecade[sortedDataPastDecade['year']==2019][['year','country','solar_energy_per_capita']].dropna()
data=solarEnergy19.sort_values(by='country',ascending=True)

plot=sns.barplot(data=data,x='country',y='solar_energy_per_capita')
plot.set_xlabel('Year')
plot.set_title('Energy Metrics Over Time')
plt.ylim(0,2500)
plt.show()

# %%
plt.figure(figsize=(100,50))

solarEnergy20=sortedDataPastDecade[sortedDataPastDecade['year']==2020][['year','country','solar_energy_per_capita']].dropna()
data=solarEnergy20.sort_values(by='country',ascending=True)

plot=sns.barplot(data=data,x='country',y='solar_energy_per_capita')
plot.set_xlabel('Year')
plot.set_title('Energy Metrics Over Time')
plt.ylim(0,2500)
plt.show()

# %% [markdown]
# # Comparing Solar and Wind Energy Data from Two Years for Select Countries

# %%
selectCountries=[]

noCountries=int(input('Enter number of countries:'))
FirstYear=int(input('Enter the first year for comparison:'))
SecondYear=int(input('Enter the second year for comparison:'))
# Out:
# Enter number of countries:8
# Enter the first year for comparison:2013
# Enter the second year for comparison:2020

# %%
for i in range(noCountries):
    country=str(input('Enter a country: '))
    selectCountries.append(country)
# Out:
# Enter a country: India
# Enter a country: China
# Enter a country: Russia
# Enter a country: United States
# Enter a country: United Kingdom
# Enter a country: Brazil
# Enter a country: Australia
# Enter a country: Argentina

# %%
selectCountries
# Out:
# ['India',
#  'China',
#  'Russia',
#  'United States',
#  'United Kingdom',
#  'Brazil',
#  'Australia',
#  'Argentina']

# %%
TwoYears=sortedDataPastDecade.set_index('year').loc[[FirstYear,SecondYear]].reset_index().dropna().drop_duplicates()
TwoYears
# Out:
#      year              country  solar_consumption  solar_elec_per_capita  \
# 8    2013               Sweden              0.090                  4.159
# 9    2013              Estonia              0.004                  0.000
# 12   2013            Sri Lanka              0.037                  0.968
# 16   2013             Colombia              0.000                  0.215
# 17   2013             Malaysia              0.361                  4.751
# ..    ...                  ...                ...                    ...
# 446  2020  Trinidad and Tobago              0.012                  0.000
# 448  2020           Kazakhstan              6.346                136.872
# 450  2020              Germany            124.836                580.541
# 451  2020              Hungary              5.850                254.649
# 454  2020                Japan            204.580                621.776
#
#      solar_energy_per_capita  wind_consumption  wind_elec_per_capita  \
# ...

# %%
selectCountriesData=TwoYears[TwoYears['country']==selectCountries[0]]

for i in selectCountries:
    concatDf=TwoYears[TwoYears['country']==i]
    selectCountriesData=pd.concat([selectCountriesData,concatDf])

selectCountriesData=selectCountriesData.reset_index().drop('index',axis=1).drop_duplicates()
selectCountriesData
# Out:
#     year         country  solar_consumption  solar_elec_per_capita  \
# 0   2013           India              8.789                  2.678
# 1   2020           India            144.779                 42.522
# 4   2013           China             21.439                  6.013
# 5   2020           China            644.166                181.405
# 6   2013          Russia              0.028                  0.000
# 7   2020          Russia              4.594                 12.745
# 8   2013   United States             41.066                 28.571
# 9   2020   United States            330.522                394.921
# 10  2013  United Kingdom              5.147                 30.931
# 11  2020  United Kingdom             31.582                196.211
# 12  2013          Brazil              0.012                  0.000
# 13  2020          Brazil             19.635                 50.574
# 14  2013       Australia              9.850                149.646
# ...

# %%
fig,axes=plt.subplots(2,2,figsize=(30,20))
fig.suptitle('Data for Select Countries Comparing Two Years')
sns.barplot(ax=axes[0,0],data=selectCountriesData,x='country',y='solar_energy_per_capita',hue='year')
sns.barplot(ax=axes[0,1],data=selectCountriesData,x='country',y='solar_consumption',hue='year')
sns.barplot(ax=axes[1,0],data=selectCountriesData,x='country',y='wind_energy_per_capita',hue='year')
sns.barplot(ax=axes[1,1],data=selectCountriesData,x='country',y='wind_consumption',hue='year')
# Out:
# <AxesSubplot:xlabel='country', ylabel='wind_consumption'>
